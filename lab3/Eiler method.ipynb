# %%
import matplotlib.pyplot as plt;
import numpy as np;

time, phi, xi, enrgy, delta = np.loadtxt('data_2.txt', unpack=True)

fig, (g1, g2) = plt.subplots(1, 2)

             
g1.scatter(phi, xi, 1)
g2.scatter(time, delta, 1)
#g3.scatter(time, xi, 1)
             
plt.show()
